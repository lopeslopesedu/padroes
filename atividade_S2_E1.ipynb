# %%
#Importando bibliotecas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
#Data set de partidas do jogo multiplayer online League of legends
#Datos Registrados de partidas de nível DIAMANTE
#Link do dataset   https://www.kaggle.com/bobbyscience/league-of-legends-diamond-ranked-games-10-min
#P

#Carregando o dataset a partir de um csv
#local_testes
#data = pd.read_csv("C:/ifes/recpad/testes/data_sets/lol/high_diamond_ranked_10min.csv",sep =",")
#git_testes
data = pd.read_csv("https://raw.githubusercontent.com/lopeslopesedu/padroes/main/high_diamond_ranked_10min.csv",sep =",")
#Quantidade de linhas e colunas do dataset
data.shape
data
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# ...

# %%
#correlação dos dados
data.corr().round(3)
# Out:
#           -0.009           0.083      0.180
# blueTotalGold                              0.060           0.312      0.889
# blueAvgLevel                               0.060           0.178      0.435
# blueTotalExperience                        0.067           0.190      0.472
# blueTotalMinionsKilled                     0.111           0.126     -0.031
# blueTotalJungleMinionsKilled              -0.023           0.018     -0.113
# blueGoldDiff                               0.079           0.379      0.654
# blueExperienceDiff                         0.078           0.241      0.584
# blueCSPerMin                               0.111           0.126     -0.031
# blueGoldPerMin                             0.060           0.312      0.889
# redWardsPlaced                             0.136          -0.019     -0.034
# redWardsDestroyed                          0.124          -0.043     -0.092
# redFirstBlood                             -0.018          -1.000     -0.269
# ...

# %%
#Selecionando as colunas
#Lado azul com first blood, Número de wards colocadas, numero de wards destruídas
X = data[['blueFirstBlood', 'blueWardsPlaced', 'blueWardsDestroyed']]
#Vitórias do lado Azul
y = data['blueWins']

# %%
#importando as bibliotecas para os proximos passos
import seaborn as sb
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#Treinando
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Calculo do MSE
yp = model.predict(X)
mse = mean_squared_error(y, yp).round(4)
print("\nMSE : ", mse)
print('R2: {}'.format(model.score(X, y).round(2)))
# Out:
# MSE :  0.2394
# R2: 0.04

# %%
#Intercept
print("Intercept: ", modelo.intercept_)

#Coef.
print("Coef.: ", model.coef_)

start = model.intercept_ - 100
stop  = model.intercept_ + 100
dtX = np.linspace(start , stop, 100).reshape(-1,1)
dtY = np.empty(dtX.shape[0])
for i in range(dtY.shape[0]):
    model.intercept_ = dtX[i]
    yp = model.predict(X)
    dtY[i] = mean_squared_error(y, yp)

#Prepara o gráfico
fig, ax = plt.subplots()
ax.set_title('Mse X Intercept', fontsize=14)
#plota o gráfico
ax = plt.plot(dtX, dtY)
# Out:
# Intercept:  0.3722903248531755
# Coef.:  [ 2.01062539e-01 -5.45532957e-05  9.36886331e-03]
